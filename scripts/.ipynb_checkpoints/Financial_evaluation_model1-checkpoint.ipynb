# %%
import os
import math
import pandas as pd
import matplotlib.pyplot  as plt
import numpy as np
from math import sqrt 
import pandas as pd
import pandas_datareader as pdr
from datetime import datetime


dataframe = pd.read_csv('USD_KZT Historical Data.csv', usecols=[1], engine='python')
dataset = dataframe.iloc[::-1]
dataset = dataset.values
dataset = dataset.astype('float32')

# %%
# !pip install pandas_ta

from numpy import array
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import TimeDistributed
from keras.layers.convolutional import Conv1D
from keras.layers.convolutional import MaxPooling1D
from sklearn.preprocessing import MinMaxScaler
import time
import keras
from keras.layers import Input, LSTM, Bidirectional
from keras.models import load_model
from matplotlib.pyplot import figure
import seaborn as sns
from sklearn.model_selection import TimeSeriesSplit
# Out:
# /bin/sh: pip: command not found
# Using TensorFlow backend.

# %%
def data_preparation2(d2,k):
    input_x, output_y = [], []
    for i in range(len(d2)-k-1):
        n = d2[i:(i+k), 0]
        input_x.append(n)
        output_y.append(d2[i + k, 0])
    return np.array(input_x), np.array(output_y)
k=10
train_size = int(len(dataset) * 0.966)
test_size = int(len(dataset) * 0.034)
train,test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
print(len(train), len(test))
train_X, train_y = data_preparation2(train, k)
test_X, test_y = data_preparation2(test,k )

train_X1 = train_X.reshape((train_X.shape[0], train_X.shape[1], 1))
test_X1 = test_X.reshape((test_X.shape[0], test_X.shape[1], 1))
# Out:
# 2689 95

# %%
start_time = time.time()
model = Sequential()
model.add(Bidirectional(LSTM(36, activation='relu'), input_shape=(10, 1)))
model.add(Dense(1))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(train_X1, train_y, epochs=40, batch_size=40, verbose=3)
elapsed_time = time.time() - start_time
print("Time went for training:", elapsed_time, "seconds")
training_scores = model.evaluate(train_X1,train_y, verbose=0)
print('Train Score: %.2f MSE (%.2f RMSE)' % (training_scores, math.sqrt(training_scores)))
# Out:
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40

# %%
test_X2=test_X1[0:len(test_X1)]
test_y2=test_y[0:len(test_X1)]

# %%
errs=[]
err=0.0
start_time = time.time()
predicted=[]
finance=0.0
for i in range(len(test_X2)):
  errs.append(0.0)  
  elX=test_X2[i:i+1]
  elY=test_y2[i:i+1]
  print("I am currently in the iteration: "+str(i))
  model.save('my_model1.h5')
  model = load_model('my_model1.h5')
  predicted.append(model.predict(test_X2[i:i+1])[0][0])
  errs[i] = model.evaluate(elX,elY, verbose=0)
  err+=errs[i]
  model.fit(elX, elY, epochs=40, batch_size=40, verbose=3)
elapsed_time = time.time() - start_time
print("Time went for training:", elapsed_time, "seconds")
# Out:
# I am currently in the iteration: 0
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 1
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 2
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 3
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 4
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 5
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 6
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 7
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 8
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 9
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 10
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 11
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 12
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 13
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 14
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 15
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 16
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 17
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 18
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 19
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 20
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 21
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 22
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 23
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 24
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 25
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 26
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 27
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 28
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 29
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 30
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 31
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 32
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 33
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 34
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 35
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 36
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 37
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 38
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 39
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 40
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 41
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 42
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 43
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 44
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 45
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 46
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 47
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 48
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 49
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 50
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 51
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 52
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 53
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 54
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 55
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 56
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 57
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 58
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 59
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 60
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 61
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 62
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 63
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 64
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 65
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 66
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 67
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 68
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 69
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 70
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 71
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 72
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 73
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 74
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 75
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 76
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 77
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 78
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 79
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 80
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 81
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 82
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# I am currently in the iteration: 83
# Epoch 1/40
# Epoch 2/40
# Epoch 3/40
# Epoch 4/40
# Epoch 5/40
# Epoch 6/40
# Epoch 7/40
# Epoch 8/40
# Epoch 9/40
# Epoch 10/40
# Epoch 11/40
# Epoch 12/40
# Epoch 13/40
# Epoch 14/40
# Epoch 15/40
# Epoch 16/40
# Epoch 17/40
# Epoch 18/40
# Epoch 19/40
# Epoch 20/40
# Epoch 21/40
# Epoch 22/40
# Epoch 23/40
# Epoch 24/40
# Epoch 25/40
# Epoch 26/40
# Epoch 27/40
# Epoch 28/40
# Epoch 29/40
# Epoch 30/40
# Epoch 31/40
# Epoch 32/40
# Epoch 33/40
# Epoch 34/40
# Epoch 35/40
# Epoch 36/40
# Epoch 37/40
# Epoch 38/40
# Epoch 39/40
# Epoch 40/40
# Time went for training: 7344.29634308815 seconds

# %%
x=test_X2[0][9][0]
dollar=10000;
tenge=3000000
pair=[]
pair.append([dollar, tenge])

# %%
for i in range(len(predicted)):
  x=test_X2[i][9][0]
  pred=predicted[i]
  #print((pred-x)/x)
  if((pred-x)/x>thresh):
    dollar+=tenge*0.2/x
    tenge=tenge*0.8
    pair.append([dollar, tenge])
  elif((pred-x)/x<-thresh):
    tenge+=dollar*0.2*x
    dollar=dollar*0.8
    pair.append([dollar, tenge])

# %%
print("initial capital:", pair[0][0]+pair[0][1]/test_X2[0][9][0])
# Out:
# initial capital: 17876.083087613013

# %%
def threshfn(thresh):
 # print(thresh)
  x=test_X2[0][9][0]
  dollar=10000;
  tenge=3000000
  pair=[]
  pair.append([dollar, tenge])
  for i in range(len(predicted)):
    x=test_X2[i][9][0]
    pred=predicted[i]
    #print((pred-x)/x)
    if((pred-x)/x>thresh):
      dollar+=tenge*0.2/x
      tenge=tenge*0.8
      pair.append([dollar, tenge])
    elif((pred-x)/x<-thresh):
      tenge+=dollar*0.2*x
      dollar=dollar*0.8
      pair.append([dollar, tenge])
  #print(pair[0][0]+pair[0][1]/test_X2[0][9][0])
  aa=pair[len(pair)-1][0]+pair[len(pair)-1][1]/test_X2[len(test_X2)-1][9][0]
  #print(aa)
  return aa

# %%
threshs2=np.linspace(0,0.03,10000)
outputs2=[]

# %%
for thr in threshs2:
  outputs2.append(threshfn(thr))
plt.plot(threshs2,outputs2)
plt.xlabel("Thesholds")
plt.ylabel("Total Money")
plt.title("Optimum threshold")
plt.show()

# %%
print("The Optimum Threshold: ", threshs2[outputs2.index(max(outputs2[400:]))])
# Out:
# The Optimum Threshold:  0.00444944494449445

# %%
print("The capital at the optimum threshold: ", outputs2[outputs2.index(max(outputs2[400:]))])
# Out:
# The capital at the optimum threshold:  17765.969375814246

# %%
# Out:
# 17809.186769935215

# %%
print("number of days tested: ", len(test_X2))
# Out:
# number of days tested:  84

# %%
print("number of days trained: ", len(train_X1))
# Out:
# number of days trained:  2678

# %%
7344/60
# Out:
# 122.4
